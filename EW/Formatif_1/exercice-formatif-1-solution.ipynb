# %%
#@title Question 1

print("Bonjour le monde !!")

# %%
#@title Question 2

nom = "Patof"

# NE PAS MODIFIER CETTE LIGNE
print("Bonjour", nom)

# %%
#@title Question 3

nom = input("Entrez votre nom: ")

# NE PAS MODIFIER CETTE LIGNE
print("Bonjour", nom)

# %%
#@title Question 4

nom = "Patof"
age = 42

# NE PAS MODIFIER CETTE LIGNE
print("Bonjour", nom, "vous avez", age, "an(s).")

# %%
#@title Question 5

nom = input("Entrez votre nom: ")
age = input("Entrez votre âge: ")

# NE PAS MODIFIER CETTE LIGNE
print("Bonjour", nom, "vous avez", age, "an(s).")
